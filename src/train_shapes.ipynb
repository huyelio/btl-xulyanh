# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
import os
import zipfile
import matplotlib.pyplot as plt

# --- 1. KẾT NỐI DRIVE VÀ GIẢI NÉN ---
from google.colab import drive
drive.mount('/content/drive')

ZIP_FILE_PATH = "/content/drive/MyDrive/shapes_dataset_v2.zip"  # Tên file zip của bạn
EXTRACT_DIR = "/content/datasets"

print(f"Đang giải nén {ZIP_FILE_PATH} vào {EXTRACT_DIR}...")
if not os.path.exists(EXTRACT_DIR):
    os.makedirs(EXTRACT_DIR)

with zipfile.ZipFile(ZIP_FILE_PATH, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_DIR)

print("Giải nén hoàn tất!")

# --- TỰ ĐỘNG TÌM DATA_DIR ---
possible_paths = [
    os.path.join(EXTRACT_DIR, "shapes_dataset_v3"),
    os.path.join(EXTRACT_DIR, "shapes_dataset_v2"),
    os.path.join(EXTRACT_DIR, "shapes_dataset_v3", "shapes_dataset_v3"),
    os.path.join(EXTRACT_DIR, "shapes_dataset_v2", "shapes_dataset_v2"),
    EXTRACT_DIR
]

DATA_DIR = None
for path in possible_paths:
    train_path = os.path.join(path, 'train')
    test_path = os.path.join(path, 'test')
    if os.path.exists(train_path) and os.path.exists(test_path):
        DATA_DIR = path
        print(f"✅ Đã tìm thấy dataset tại: {DATA_DIR}")
        break

if DATA_DIR is None:
    raise FileNotFoundError("❌ Không tìm thấy thư mục train/test!")

# Kiểm tra số lượng classes
train_path = os.path.join(DATA_DIR, 'train')
classes = sorted(os.listdir(train_path))
NUM_CLASSES = len(classes)
print(f"Số lượng classes: {NUM_CLASSES}")
print(f"Classes: {classes}")

# --- CẤU HÌNH ---
IMG_SIZE = 64
BATCH_SIZE = 32
EPOCHS = 30

# --- 2. DATA AUGMENTATION LAYER ---
data_augmentation = keras.Sequential([
    layers.RandomRotation(0.3),  # Xoay ±30 độ
    layers.RandomTranslation(0.15, 0.15),  # Dịch chuyển 15%
    layers.RandomZoom(0.15),  # Zoom in/out 15%
    layers.RandomContrast(0.2),  # Thay đổi contrast
])

# --- 3. TẢI DỮ LIỆU ---
print("\nĐang tải tập huấn luyện (train)...")
train_dataset = tf.keras.utils.image_dataset_from_directory(
    os.path.join(DATA_DIR, 'train'),
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    color_mode='grayscale',
    shuffle=True,
    seed=42
)

print("Đang tải tập kiểm tra (test)...")
test_dataset = tf.keras.utils.image_dataset_from_directory(
    os.path.join(DATA_DIR, 'test'),
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    color_mode='grayscale',
    shuffle=False
)

class_names = train_dataset.class_names
print(f"Đã tìm thấy {len(class_names)} lớp: {class_names}")

# --- 4. CHUẨN HÓA & AUGMENTATION ---
normalization_layer = layers.Rescaling(1./255)

def prepare_train(x, y):
    x = normalization_layer(x)
    x = data_augmentation(x, training=True)
    return x, y

def prepare_test(x, y):
    x = normalization_layer(x)
    return x, y

train_dataset = train_dataset.map(prepare_train, num_parallel_calls=tf.data.AUTOTUNE)
test_dataset = test_dataset.map(prepare_test, num_parallel_calls=tf.data.AUTOTUNE)

train_dataset = train_dataset.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
test_dataset = test_dataset.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# --- 5. XÂY DỰNG MODEL CẢI TIẾN ---
model = models.Sequential([
    layers.Input(shape=(IMG_SIZE, IMG_SIZE, 1)),

    # Block 1
    layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Block 2
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Block 3
    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Dense layers
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

model.summary()

# --- 6. COMPILE VỚI OPTIMIZER TỐT HƠN ---
optimizer = keras.optimizers.Adam(learning_rate=0.001)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy', keras.metrics.TopKCategoricalAccuracy(k=3, name='top_3_accuracy')]
)

# --- 7. CALLBACKS ---
callbacks = [
    # Giảm learning rate khi accuracy không cải thiện
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        min_lr=1e-7,
        verbose=1
    ),

    # Dừng sớm nếu không cải thiện
    EarlyStopping(
        monitor='val_loss',
        patience=7,
        restore_best_weights=True,
        verbose=1
    ),

    # Lưu model tốt nhất
    ModelCheckpoint(
        'best_shapes_model_v3.h5',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

# --- 8. HUẤN LUYỆN ---
print("\n" + "="*60)
print("BẮT ĐẦU HUẤN LUYỆN")
print("="*60)
history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=test_dataset,
    callbacks=callbacks,
    verbose=1
)

# --- 9. ĐÁNH GIÁ ---
print("\n" + "="*60)
print("ĐÁNH GIÁ TRÊN TẬP TEST")
print("="*60)
test_loss, test_acc, test_top3 = model.evaluate(test_dataset, verbose=1)
print(f"\n📊 KẾT QUẢ CUỐI CÙNG:")
print(f"  • Test Accuracy: {test_acc*100:.2f}%")
print(f"  • Test Top-3 Accuracy: {test_top3*100:.2f}%")
print(f"  • Test Loss: {test_loss:.4f}")

# --- 10. VẼ BIỂU ĐỒ ---
print("\nĐang tạo biểu đồ training history...")
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Val Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 2)
plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Val Loss', linewidth=2)
plt.title('Model Loss', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 3)
plt.plot(history.history['top_3_accuracy'], label='Train Top-3', linewidth=2)
plt.plot(history.history['val_top_3_accuracy'], label='Val Top-3', linewidth=2)
plt.title('Top-3 Accuracy', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('training_history.png', dpi=150, bbox_inches='tight')
print("✅ Đã lưu biểu đồ vào 'training_history.png'")

# --- 11. LƯU MODEL CUỐI CÙNG ---
model_filename = 'shapes_model_v3_final.h5'
model.save(model_filename)
print(f"\n✅ Đã lưu model cuối cùng vào '{model_filename}'")

# --- 12. TẢI VỀ ---
print("\n" + "="*60)
print("TẢI FILE VỀ MÁY")
print("="*60)
try:
    from google.colab import files

    print("Đang tải các file về máy tính của bạn...")
    files.download(model_filename)
    print(f"  ✅ {model_filename}")

    files.download('best_shapes_model_v3.h5')
    print(f"  ✅ best_shapes_model_v3.h5")

    files.download('training_history.png')
    print(f"  ✅ training_history.png")

    print("\n🎉 Hoàn tất! Tất cả file đã được tải về.")
except Exception as e:
    print(f"⚠️ Không thể tự động tải file: {e}")
    print("Bạn có thể tải thủ công từ file browser bên trái.")

# --- 13. TỔNG KẾT ---
print("\n" + "="*60)
print("TỔNG KẾT")
print("="*60)
print(f"✅ Model đã được huấn luyện với {EPOCHS} epochs")
print(f"✅ Dataset: {NUM_CLASSES} classes, {len(classes)} loại hình")
print(f"✅ Final Validation Accuracy: {test_acc*100:.2f}%")
print(f"✅ File models đã được lưu và tải về")
print("="*60)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Đang giải nén /content/drive/MyDrive/shapes_dataset_v2.zip vào /content/datasets...
# Giải nén hoàn tất!
# ✅ Đã tìm thấy dataset tại: /content/datasets/shapes_dataset_v3
# Số lượng classes: 10
# Classes: ['arrow', 'circle', 'cross', 'hexagon', 'octagon', 'pentagon', 'rectangle', 'rhombus', 'star', 'triangle']
#
# Đang tải tập huấn luyện (train)...
# Found 16000 files belonging to 10 classes.
# Đang tải tập kiểm tra (test)...
# Found 4000 files belonging to 10 classes.
# Đã tìm thấy 10 lớp: ['arrow', 'circle', 'cross', 'hexagon', 'octagon', 'pentagon', 'rectangle', 'rhombus', 'star', 'triangle']
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# ...
